# %% [markdown]
# # DATA VISUALIZATION
#
# ### Link de Metricas GDS
#
# https://support.google.com/datastudio/topic/7019880?hl=es&ref_topic=7570421
#
# ### Que grafico usar?
#
#
# https://looker.com/blog/different-types-graphs-charts-uses
#
# https://blog.hubspot.com/marketing/types-of-graphs-for-data-visualization
#
# https://datastudio.google.com/open/1psCE1hUUw-kyXhhOYx38coNbtGyvI_6_

# %% [markdown]
# # WEB SCRAPPING
#
# ### Lineamientos de Robots
#
# https://developers.google.com/search/docs/advanced/robots/create-robots-txt?hl=es&visit_id=637524844556668501-1024973828&rd=1
#
# ### Scrap
#
# http://toscrape.com
#
# https://github.com/fer2002743/web-scraping/tree/master
